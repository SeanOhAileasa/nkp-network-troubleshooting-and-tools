# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-troubleshooting-and-tools/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Network Troubleshooting Methodology``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Network Troubleshooting Methodology](#networkTroubleshooting)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTroubleshooting"></a>
# ***
# ### Network Troubleshooting Methodology
# ***

# %% [markdown]
# Troubleshooting complex network problems, may find that the resolution is not as obvious as you might hope.

# %% [markdown]
# Going to step through a methodology that should help you troubleshoot any problem you run into.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting a Network
# ***

# %% [markdown]
# This is the flowchart of that network troubleshooting methodology, and we’re going to step through each section of this flow and describe how it can help you solve those really difficult problems.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting a Network - Identify the Problem
# ***

# %% [markdown]
# The first thing you want to do is identify the problem.

# %% [markdown]
# This may not be as straightforward as you might think, first need to collect as much information as possible about the issue that’s occurring.

# %% [markdown]
# In the best possible scenario, be able to duplicate this problem on demand, this will help later as we go through a number of testing phases to make sure that we are able to resolve this issue.

# %% [markdown]
# When a problem happens on the network, it usually affects more than one device, and sometimes it affects those devices in different ways.

# %% [markdown]
# You want to be sure to document all of the symptoms that may be occurring.

# %% [markdown]
# Even if they are very different between different devices, you may find that a single problem is causing all of these different systems across these different devices.

# %% [markdown]
# Many times, these issues will be identified by the end users, so they may be able to provide you with a lot more detail of what’s really happening.

# %% [markdown]
# Should question your users to find out what they’re seeing and if any error messages are appearing.

# %% [markdown]
# Already discussed the importance of the change control process and knowing exactly what is changing in your environment.

# %% [markdown]
# Without some type of formal change control process, someone may be able to make an unscheduled change that would affect many different people, so when an error or network problem occurs, you may want to find out what was the last thing that changed on this network that could have affected all of these users.

# %% [markdown]
# There’s also going to be times when you’re examining a number of different problems that may not actually be related to each other.

# %% [markdown]
# It’s always best to separate all of these different issues out so that you can approach and try to resolve each issue individually.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting a Network - Establish a Theory
# ***

# %% [markdown]
# Now that you’ve collected as much information as possible, you can examine all of these details to begin establishing a theory of what you think might be going wrong.

# %% [markdown]
# Since the simpler explanation is often the most likely reason for the issue, that may be a good place to start.

# %% [markdown]
# Will want to consider every possible thing that might be causing this issue, maybe start with things that aren’t completely obvious.

# %% [markdown]
# You could start from the top of the OSI model with the way the application is working and work your way to the bottom or you may want to start with the bottom with the cabling and wiring in your infrastructure and work your way up from there.

# %% [markdown]
# Will want to list out every possible cause for this problem, your list might start with the easy theories at the top, but of course include all of the more complex theories in this list as well.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting a Network - Evaluate Results
# ***

# %% [markdown]
# Now that we have a list of theories on how to resolve this issue, we can now test those theories.

# %% [markdown]
# We may want to go into a lab and if we are able to recreate this problem in the lab, then we can apply each theory until we find the one that happens to resolve the issue.

# %% [markdown]
# If you tried the first theory, you may want to reset everything and try the second theory or the third and if you run out of theories, you may want to go back and think of other things that might be causing this problem.

# %% [markdown]
# This might be a good time to bring in an expert who knows about the application or the infrastructure, and they can give some theories and possible resolutions to test in the lab.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting a Network - Establish Plan of Action
# ***

# %% [markdown]
# Once you’ve tested a theory and found that the theory is going to resolve this issue, you can then begin putting together a plan of action.

# %% [markdown]
# This is how you would implement this fix into a production network.

# %% [markdown]
# You want to be sure that you’re able to do this with a minimum amount of impact to the production network, and sometimes you have to do this after hours when nobody else is working on the network.

# %% [markdown]
# Want to be able to implement this with a minimum amount of impact to production traffic, so often, you’ll have to do this after hours.

# %% [markdown]
# A best practice is to document the exact steps that will be required to solve this particular problem.

# %% [markdown]
# If it’s replacing a cable, then the process will be relatively straightforward.

# %% [markdown]
# But if you’re upgrading software in a switch, a router, or a firewall, there may be additional tasks involved in performing this plan of action.

# %% [markdown]
# Also want some alternatives if your plan doesn’t go as designed, for example, you may run into problems when upgrading the software in a firewall.

# %% [markdown]
# So you may need an additional firewall or way to rollback to the previous version.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting a Network - Implement the Plan
# ***

# %% [markdown]
# Now that the plan of action is documented, can take that to your change control team, and they can give you a window when you can implement that change.

# %% [markdown]
# The actual fixing of the issue is probably going to be during off hours during non-production times, and you may need to bring in other people to assist, especially if your window is very small.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting a Network - Verify Full System Functionality
# ***

# %% [markdown]
# Once you have executed on your plan of action, your job isn’t done yet, need to make sure that all of these changes actually resolved the problem.

# %% [markdown]
# So now that the changes have been implemented, we now need to perform some tests.

# %% [markdown]
# We may want to bring in the end users who first experienced this problem so that they can run through exactly the same scenario to tell you if the problem is resolved or if the problem still exists.

# %% [markdown]
# This might also be a good time to implement some preventive measures, that way, we can either be informed that the problem is occurring, or we can provide alternatives that we can implement if that problem happens again.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting a Network - Document Findings
# ***

# %% [markdown]
# After the problem has been resolved, this is a perfect time to document the entire process from the very beginning to the very end.

# %% [markdown]
# Want to provide as much information as possible, so if somebody runs into this issue again, they can simply search your knowledgebase, find that particular error that popped up, and know exactly the process you used to solve this last time.

# %% [markdown]
# Many organizations have a help desk with case notes that they can reference, or you might have a separate knowledge base or wiki that you create where you’re storing all of this important information for the future.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A document that was created a number of years ago but still shows the importance of keeping this documentation over time is from [Google Research](https://static.googleusercontent.com/media/research.google.com/en//archive/disk_failures.pdf), where they documented the failure trends in a large disk drive population, and because they were keeping extensive data over a long period of time, they were able to tell when a drive was starting to fail based on the types of errors that they were receiving.

# %% [markdown]
# Being able to store all of this important information, being able to go back in time to see what happened, becomes a very important part of maintaining a network for the future.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Troubleshooting a Network - Summary
# ***

# %% [markdown]
# Start with gathering as much information as possible, asking users about what they’re seeing, and documenting any specific error messages.

# %% [markdown]
# Then we want to be able to create a number of theories that might solve this particular problem.

# %% [markdown]
# Once we have this list, we want to be able to put it in the lab and try testing each one of these theories until we find the one that actually resolves the issue.

# %% [markdown]
# From there, we can create a plan of action and document any possible problems that might occur.

# %% [markdown]
# We can then get a time to implement the issue and put it into our production environment and then we can verify and test and make sure that the entire system is now working as expected.

# %% [markdown]
# Finally, we want to document everything that we did from the very beginning of our troubleshooting process all the way through to the end.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
