# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/nkp-network-troubleshooting-and-tools/blob/main/README.md) >
#
# ## CompTIA Network+ - Course Material 2022
# ### Topic: ``Software Tools``
# ***

# %% [markdown]
# Course material for the ``CompTIA Network+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [Software Tools](#networkTools)

# %% [markdown]
# <hr width=50%;>

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="networkTools"></a>
# ***
# ### Software Tools
# ***

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Protocol Anlaysers
# ***

# %% [markdown]
# If you need to troubleshoot network slowdowns or application traffic flows, then you need to use a protocol analyzer.

# %% [markdown]
# This will be able to capture every frame that’s going back and forth between devices across the network, or capture traffic as it’s going through your wireless networks.

# %% [markdown]
# These protocol analyzers can be separate pieces of software that you would run on your computer, or this packet capture function may be built into the routers, switches, and other devices in your network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Using these protocol decodes, we can see a frame-by-frame representation of exactly what’s gone through the network.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# We can see the hexadecimal breakdown of the data within those frames.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Can get a protocol decode that gives us a plain English explanation of exactly what’s inside of that frame.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These protocol analyzers are not only good for providing information about network troubleshooting, but if you’re storing large amounts of these packets, you can also find security issues that may be hiding in those frames.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Network / Port Scanners
# ***

# %% [markdown]
# Another good software tool for any network administrator is a good port scanner.

# %% [markdown]
# This will be able to scan IP addresses or a range of IP addresses, and find all of the open ports that may be available on those devices.

# %% [markdown]
# More advanced port scanners can also tell you information about what operating system happens to be on that device and what type of services are running on that device.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Can pick a range of addresses to see who might respond to the scans that you’re running, and some of these port scanners can build graphical representations of the results and now we can visually see exactly what the port scanners found.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These port scanners are very good at finding and querying devices.

# %% [markdown]
# So if you’re concerned that there may be a rogue device on the network, these port scanners are very good at locating it.

# %% [markdown]
# One of the most popular port scanners in the world is ``Nmap`` and the graphical ``Zenmap`` that works along with it, or you can also download other port scanners like ``Angry IP Scanner``, to find all of these different devices, operating systems, and services on your network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wireless Packet Analysis
# ***

# %% [markdown]
# Troubleshooting a wireless network can be a challenge.

# %% [markdown]
# Obviously, wireless is going to be sending signal to whoever might be in the vicinity.

# %% [markdown]
# Any device that wants to listen in to your network is able to do that because everything is going through the air.

# %% [markdown]
# If you’re going to use software that’s listening in to this network, then that software needs to disable the transmission function of your wireless card because if you’re transmitting, you won’t be able to hear anything else on the wireless network.

# %% [markdown]
# You also want to be sure you have the right kind of wireless interface card that’s able to perform these analysis functions you may need a specific adapter card or wireless chipset to be able to put the card into this wireless analysis mode.

# %% [markdown]
# But once you have the right adapter card, you’re able to gather a lot of wireless-specific data.

# %% [markdown]
# Not only can you see the IP traffic going across the wireless network, you can see the wireless protocols, the signal-to-noise ratio, channel information, and other wireless details.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Wireless packet Analysis - Wireshark
# ***

# %% [markdown]
# Using Wireshark on a wireless network can provide much of this information, and a number of third party tools can also gather these details from a wireless network.

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="___"></a>
# ***
# ###### Speed Test Sites
# ***

# %% [markdown]
# Speed test sites that are available on the internet are a great resource if you need to quickly perform some bandwidth testing.

# %% [markdown]
# These sites work by transferring a file and then determining how long it took for that file to be transferred.

# %% [markdown]
# Many of them will perform download and upload tests, and they’ll use different size files to be able to test different amounts of throughput.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These can also be used if you’re making any change to the network, you might want to run a speed test before you install a new firewall, and then run the speed test after you’ve installed the new firewall to see if there was any impact to the overall throughput.

# %% [markdown]
# You might also want to try running speed tests at different times of the day, as the amount of utilization on the network changes, you’ll be able to see the impact to the overall throughput to the internet.

# %% [markdown]
# You might want to try different speed test sites, as well, not every speed test site is built exactly the same.

# %% [markdown]
# They might have a different number of servers, they might have more or less bandwidth, depending on what point of presence is being used, and the testing methodology may change depending on what service you’re using.

# %% [markdown]
# Some very common third party test sites are ``SpeedOf.Me``, ``speedtest.net``, and ``testmy.net``.

# %% [markdown]
# If you’re on an ISP, they may ask you to perform speed tests on their local network. So if you’re on Comcast, you may be using speedtest.comcast.net, and AT&T has ``att.com/speedtest``.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# On the Comcast network, ``speedtest.comcast.net``, which redirects to ``speedtest.xfinity.com``.

# %% [markdown]
# Start test to test our internet speed - the first phase will be a download test.

# %% [markdown]
# So it will run traffic from their servers through the Comcast network down to my computer.

# %% [markdown]
# Once the download test is complete, it shifts gears and performs an upload test and finally, it shows me what the speed results were for the download and upload from my network connection.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;J. "Professor" Messer, "CompTIA Network+ (N10-007) Course Notes," [professormesser.com](https://web.archive.org/web/20220404153917/https://www.professormesser.com/network-plus/n10-007/n10-007-training-course/), March 2019.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
